# %%
from tensorflow import keras
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import make_classification
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Reading CSV housing data

# %%
column_names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
df = pd.read_csv('./housing.csv', header=None, delimiter=r"\s+", names=column_names)
df.rename(columns = {'Target':'MEDV'}, inplace = True)

# %%
df.head(5)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
df.shape
# Out:
# (506, 14)

# %%
### Extracting features(x) and target variable(y)
x = df.drop('MEDV', axis=1)
y = df['MEDV']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
import numpy as np
from sklearn.metrics import mean_squared_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
### Building Neural network model
model = Sequential()
model.add(Dense(64, input_dim=x_train.shape[1], activation = 'relu'))
model.add(Dense(32, activation = 'relu'))
model.add(Dense(1, activation = 'linear'))

# %%
### Compiling the model
model.compile(optimizer='adam', loss='mean_squared_error', metrics = 'mae')

# %%
### Training the model
model.fit(x_train, y_train, epochs = 100, batch_size = 32, validation_data=(x_test, y_test), verbose=2)
# Out:
# Epoch 1/100
# 13/13 - 0s - loss: 8.2686 - mae: 2.0874 - val_loss: 12.3889 - val_mae: 2.3206 - 98ms/epoch - 8ms/step
# Epoch 2/100
# 13/13 - 0s - loss: 8.1255 - mae: 2.0738 - val_loss: 12.4439 - val_mae: 2.3373 - 81ms/epoch - 6ms/step
# Epoch 3/100
# 13/13 - 0s - loss: 8.0183 - mae: 2.0654 - val_loss: 12.3747 - val_mae: 2.3345 - 83ms/epoch - 6ms/step
# Epoch 4/100
# 13/13 - 0s - loss: 8.0895 - mae: 2.0606 - val_loss: 12.2595 - val_mae: 2.2888 - 83ms/epoch - 6ms/step
# Epoch 5/100
# 13/13 - 0s - loss: 7.9843 - mae: 2.0574 - val_loss: 12.2634 - val_mae: 2.3135 - 94ms/epoch - 7ms/step
# Epoch 6/100
# 13/13 - 0s - loss: 7.9057 - mae: 2.0466 - val_loss: 12.1858 - val_mae: 2.3053 - 68ms/epoch - 5ms/step
# Epoch 7/100
# 13/13 - 0s - loss: 7.8370 - mae: 2.0387 - val_loss: 12.2547 - val_mae: 2.3026 - 59ms/epoch - 5ms/step
# Epoch 8/100
# 13/13 - 0s - loss: 7.9858 - mae: 2.0615 - val_loss: 12.2363 - val_mae: 2.3184 - 81ms/epoch - 6ms/step
# Epoch 9/100
# 13/13 - 0s - loss: 7.8924 - mae: 2.0394 - val_loss: 12.1629 - val_mae: 2.3006 - 107ms/epoch - 8ms/step
# Epoch 10/100
# 13/13 - 0s - loss: 7.7698 - mae: 2.0388 - val_loss: 12.1747 - val_mae: 2.3005 - 95ms/epoch - 7ms/step
# Epoch 11/100
# 13/13 - 0s - loss: 7.7107 - mae: 2.0210 - val_loss: 12.1552 - val_mae: 2.2883 - 101ms/epoch - 8ms/step
# Epoch 12/100
# 13/13 - 0s - loss: 7.6595 - mae: 2.0209 - val_loss: 12.1812 - val_mae: 2.2954 - 91ms/epoch - 7ms/step
# Epoch 13/100
# 13/13 - 0s - loss: 7.6434 - mae: 2.0217 - val_loss: 12.1808 - val_mae: 2.2886 - 102ms/epoch - 8ms/step
# Epoch 14/100
# 13/13 - 0s - loss: 7.5751 - mae: 2.0087 - val_loss: 12.0417 - val_mae: 2.2942 - 87ms/epoch - 7ms/step
# Epoch 15/100
# 13/13 - 0s - loss: 7.5297 - mae: 2.0116 - val_loss: 12.0637 - val_mae: 2.2940 - 85ms/epoch - 7ms/step
# Epoch 16/100
# 13/13 - 0s - loss: 7.5249 - mae: 2.0087 - val_loss: 12.0955 - val_mae: 2.2763 - 110ms/epoch - 8ms/step
# Epoch 17/100
# 13/13 - 0s - loss: 7.4636 - mae: 2.0023 - val_loss: 11.9887 - val_mae: 2.2830 - 94ms/epoch - 7ms/step
# Epoch 18/100
# 13/13 - 0s - loss: 7.3859 - mae: 1.9877 - val_loss: 11.9171 - val_mae: 2.2669 - 96ms/epoch - 7ms/step
# Epoch 19/100
# 13/13 - 0s - loss: 7.3858 - mae: 1.9838 - val_loss: 11.9720 - val_mae: 2.2782 - 103ms/epoch - 8ms/step
# Epoch 20/100
# 13/13 - 0s - loss: 7.3192 - mae: 1.9819 - val_loss: 11.9770 - val_mae: 2.2863 - 115ms/epoch - 9ms/step
# Epoch 21/100
# 13/13 - 0s - loss: 7.2821 - mae: 1.9759 - val_loss: 11.9230 - val_mae: 2.2601 - 98ms/epoch - 8ms/step
# Epoch 22/100
# 13/13 - 0s - loss: 7.2977 - mae: 1.9815 - val_loss: 11.8645 - val_mae: 2.2685 - 85ms/epoch - 7ms/step
# Epoch 23/100
# 13/13 - 0s - loss: 7.2277 - mae: 1.9717 - val_loss: 11.9283 - val_mae: 2.2810 - 98ms/epoch - 8ms/step
# Epoch 24/100
# 13/13 - 0s - loss: 7.1503 - mae: 1.9538 - val_loss: 11.8534 - val_mae: 2.2539 - 88ms/epoch - 7ms/step
# Epoch 25/100
# 13/13 - 0s - loss: 7.1474 - mae: 1.9601 - val_loss: 11.7383 - val_mae: 2.2528 - 95ms/epoch - 7ms/step
# Epoch 26/100
# 13/13 - 0s - loss: 7.0971 - mae: 1.9506 - val_loss: 11.7819 - val_mae: 2.2545 - 116ms/epoch - 9ms/step
# Epoch 27/100
# 13/13 - 0s - loss: 7.1243 - mae: 1.9523 - val_loss: 11.7732 - val_mae: 2.2513 - 104ms/epoch - 8ms/step
# Epoch 28/100
# 13/13 - 0s - loss: 7.0276 - mae: 1.9401 - val_loss: 11.8154 - val_mae: 2.2780 - 100ms/epoch - 8ms/step
# Epoch 29/100
# 13/13 - 0s - loss: 6.9770 - mae: 1.9385 - val_loss: 11.6385 - val_mae: 2.2456 - 102ms/epoch - 8ms/step
# Epoch 30/100
# 13/13 - 0s - loss: 6.9854 - mae: 1.9390 - val_loss: 11.6936 - val_mae: 2.2443 - 87ms/epoch - 7ms/step
# Epoch 31/100
# 13/13 - 0s - loss: 6.9094 - mae: 1.9286 - val_loss: 11.7034 - val_mae: 2.2569 - 99ms/epoch - 8ms/step
# Epoch 32/100
# 13/13 - 0s - loss: 6.9103 - mae: 1.9319 - val_loss: 11.6663 - val_mae: 2.2489 - 89ms/epoch - 7ms/step
# Epoch 33/100
# 13/13 - 0s - loss: 6.8472 - mae: 1.9248 - val_loss: 11.6726 - val_mae: 2.2620 - 88ms/epoch - 7ms/step
# Epoch 34/100
# 13/13 - 0s - loss: 6.8696 - mae: 1.9272 - val_loss: 11.6099 - val_mae: 2.2565 - 111ms/epoch - 9ms/step
# Epoch 35/100
# 13/13 - 0s - loss: 6.7680 - mae: 1.9063 - val_loss: 11.5508 - val_mae: 2.2183 - 86ms/epoch - 7ms/step
# Epoch 36/100
# 13/13 - 0s - loss: 6.7704 - mae: 1.9095 - val_loss: 11.6093 - val_mae: 2.2443 - 87ms/epoch - 7ms/step
# Epoch 37/100
# 13/13 - 0s - loss: 6.6994 - mae: 1.9007 - val_loss: 11.5589 - val_mae: 2.2373 - 83ms/epoch - 6ms/step
# Epoch 38/100
# 13/13 - 0s - loss: 6.7358 - mae: 1.9144 - val_loss: 11.5253 - val_mae: 2.2406 - 77ms/epoch - 6ms/step
# Epoch 39/100
# 13/13 - 0s - loss: 6.6471 - mae: 1.8886 - val_loss: 11.4460 - val_mae: 2.2062 - 101ms/epoch - 8ms/step
# Epoch 40/100
# 13/13 - 0s - loss: 6.5930 - mae: 1.8852 - val_loss: 11.4622 - val_mae: 2.2348 - 94ms/epoch - 7ms/step
# Epoch 41/100
# 13/13 - 0s - loss: 6.5502 - mae: 1.8836 - val_loss: 11.4306 - val_mae: 2.2232 - 85ms/epoch - 7ms/step
# Epoch 42/100
# 13/13 - 0s - loss: 6.5858 - mae: 1.8942 - val_loss: 11.3785 - val_mae: 2.2116 - 87ms/epoch - 7ms/step
# Epoch 43/100
# 13/13 - 0s - loss: 6.5106 - mae: 1.8770 - val_loss: 11.4301 - val_mae: 2.2286 - 88ms/epoch - 7ms/step
# Epoch 44/100
# 13/13 - 0s - loss: 6.4825 - mae: 1.8834 - val_loss: 11.4139 - val_mae: 2.2230 - 90ms/epoch - 7ms/step
# Epoch 45/100
# 13/13 - 0s - loss: 6.3914 - mae: 1.8583 - val_loss: 11.2783 - val_mae: 2.2003 - 80ms/epoch - 6ms/step
# Epoch 46/100
# 13/13 - 0s - loss: 6.4068 - mae: 1.8674 - val_loss: 11.3561 - val_mae: 2.2124 - 102ms/epoch - 8ms/step
# Epoch 47/100
# 13/13 - 0s - loss: 6.4033 - mae: 1.8593 - val_loss: 11.3141 - val_mae: 2.2023 - 140ms/epoch - 11ms/step
# Epoch 48/100
# 13/13 - 0s - loss: 6.3762 - mae: 1.8586 - val_loss: 11.2960 - val_mae: 2.2075 - 101ms/epoch - 8ms/step
# Epoch 49/100
# 13/13 - 0s - loss: 6.3547 - mae: 1.8696 - val_loss: 11.3574 - val_mae: 2.2326 - 111ms/epoch - 9ms/step
# Epoch 50/100
# 13/13 - 0s - loss: 6.3476 - mae: 1.8579 - val_loss: 11.2436 - val_mae: 2.2000 - 101ms/epoch - 8ms/step
# Epoch 51/100
# 13/13 - 0s - loss: 6.2889 - mae: 1.8529 - val_loss: 11.2981 - val_mae: 2.2035 - 86ms/epoch - 7ms/step
# Epoch 52/100
# 13/13 - 0s - loss: 6.1419 - mae: 1.8177 - val_loss: 11.2191 - val_mae: 2.2127 - 82ms/epoch - 6ms/step
# Epoch 53/100
# 13/13 - 0s - loss: 6.2392 - mae: 1.8447 - val_loss: 11.1864 - val_mae: 2.1987 - 81ms/epoch - 6ms/step
# Epoch 54/100
# 13/13 - 0s - loss: 6.1739 - mae: 1.8182 - val_loss: 11.2323 - val_mae: 2.1856 - 72ms/epoch - 6ms/step
# Epoch 55/100
# 13/13 - 0s - loss: 6.1914 - mae: 1.8439 - val_loss: 11.3785 - val_mae: 2.2468 - 59ms/epoch - 5ms/step
# Epoch 56/100
# 13/13 - 0s - loss: 6.0663 - mae: 1.8284 - val_loss: 11.1687 - val_mae: 2.1764 - 84ms/epoch - 6ms/step
# Epoch 57/100
# 13/13 - 0s - loss: 6.2379 - mae: 1.8471 - val_loss: 11.1478 - val_mae: 2.1980 - 65ms/epoch - 5ms/step
# Epoch 58/100
# 13/13 - 0s - loss: 6.3240 - mae: 1.8544 - val_loss: 11.0336 - val_mae: 2.1667 - 79ms/epoch - 6ms/step
# Epoch 59/100
# 13/13 - 0s - loss: 6.0995 - mae: 1.8160 - val_loss: 11.2675 - val_mae: 2.2306 - 62ms/epoch - 5ms/step
# Epoch 60/100
# 13/13 - 0s - loss: 6.0641 - mae: 1.8255 - val_loss: 11.1756 - val_mae: 2.1877 - 65ms/epoch - 5ms/step
# Epoch 61/100
# 13/13 - 0s - loss: 6.0476 - mae: 1.8143 - val_loss: 11.0990 - val_mae: 2.1862 - 75ms/epoch - 6ms/step
# Epoch 62/100
# 13/13 - 0s - loss: 5.9724 - mae: 1.8123 - val_loss: 11.0813 - val_mae: 2.1889 - 64ms/epoch - 5ms/step
# Epoch 63/100
# 13/13 - 0s - loss: 5.8735 - mae: 1.7924 - val_loss: 11.0124 - val_mae: 2.1874 - 76ms/epoch - 6ms/step
# Epoch 64/100
# 13/13 - 0s - loss: 5.9044 - mae: 1.7992 - val_loss: 11.0011 - val_mae: 2.1814 - 66ms/epoch - 5ms/step
# Epoch 65/100
# 13/13 - 0s - loss: 5.7905 - mae: 1.7728 - val_loss: 10.9966 - val_mae: 2.1726 - 64ms/epoch - 5ms/step
# Epoch 66/100
# 13/13 - 0s - loss: 5.8126 - mae: 1.7745 - val_loss: 11.0067 - val_mae: 2.1738 - 74ms/epoch - 6ms/step
# Epoch 67/100
# 13/13 - 0s - loss: 5.8193 - mae: 1.7980 - val_loss: 11.0142 - val_mae: 2.1936 - 78ms/epoch - 6ms/step
# Epoch 68/100
# 13/13 - 0s - loss: 5.7414 - mae: 1.7741 - val_loss: 10.9230 - val_mae: 2.1481 - 68ms/epoch - 5ms/step
# Epoch 69/100
# 13/13 - 0s - loss: 5.7324 - mae: 1.7673 - val_loss: 10.9363 - val_mae: 2.1686 - 77ms/epoch - 6ms/step
# Epoch 70/100
# 13/13 - 0s - loss: 5.7002 - mae: 1.7655 - val_loss: 10.9436 - val_mae: 2.1844 - 76ms/epoch - 6ms/step
# Epoch 71/100
# 13/13 - 0s - loss: 5.6513 - mae: 1.7621 - val_loss: 10.9069 - val_mae: 2.1699 - 63ms/epoch - 5ms/step
# Epoch 72/100
# 13/13 - 0s - loss: 5.5904 - mae: 1.7510 - val_loss: 10.8823 - val_mae: 2.1661 - 76ms/epoch - 6ms/step
# Epoch 73/100
# 13/13 - 0s - loss: 5.6286 - mae: 1.7622 - val_loss: 10.8451 - val_mae: 2.1602 - 79ms/epoch - 6ms/step
# Epoch 74/100
# 13/13 - 0s - loss: 5.5140 - mae: 1.7436 - val_loss: 10.8698 - val_mae: 2.1732 - 70ms/epoch - 5ms/step
# Epoch 75/100
# 13/13 - 0s - loss: 5.5927 - mae: 1.7706 - val_loss: 10.8273 - val_mae: 2.1631 - 61ms/epoch - 5ms/step
# Epoch 76/100
# 13/13 - 0s - loss: 5.5103 - mae: 1.7431 - val_loss: 10.8488 - val_mae: 2.1715 - 64ms/epoch - 5ms/step
# Epoch 77/100
# 13/13 - 0s - loss: 5.4691 - mae: 1.7359 - val_loss: 10.8338 - val_mae: 2.1558 - 69ms/epoch - 5ms/step
# Epoch 78/100
# 13/13 - 0s - loss: 5.4523 - mae: 1.7340 - val_loss: 10.8061 - val_mae: 2.1615 - 86ms/epoch - 7ms/step
# Epoch 79/100
# 13/13 - 0s - loss: 5.4548 - mae: 1.7323 - val_loss: 10.7552 - val_mae: 2.1447 - 77ms/epoch - 6ms/step
# Epoch 80/100
# 13/13 - 0s - loss: 5.4585 - mae: 1.7312 - val_loss: 10.7594 - val_mae: 2.1556 - 79ms/epoch - 6ms/step
# Epoch 81/100
# 13/13 - 0s - loss: 5.4205 - mae: 1.7430 - val_loss: 10.7702 - val_mae: 2.1592 - 71ms/epoch - 5ms/step
# Epoch 82/100
# 13/13 - 0s - loss: 5.3999 - mae: 1.7135 - val_loss: 10.7305 - val_mae: 2.1568 - 64ms/epoch - 5ms/step
# Epoch 83/100
# 13/13 - 0s - loss: 5.3548 - mae: 1.7264 - val_loss: 10.6821 - val_mae: 2.1481 - 60ms/epoch - 5ms/step
# Epoch 84/100
# 13/13 - 0s - loss: 5.2923 - mae: 1.7019 - val_loss: 10.7071 - val_mae: 2.1549 - 61ms/epoch - 5ms/step
# Epoch 85/100
# 13/13 - 0s - loss: 5.3583 - mae: 1.7331 - val_loss: 10.6713 - val_mae: 2.1497 - 74ms/epoch - 6ms/step
# Epoch 86/100
# 13/13 - 0s - loss: 5.2828 - mae: 1.6952 - val_loss: 10.7321 - val_mae: 2.1535 - 77ms/epoch - 6ms/step
# Epoch 87/100
# 13/13 - 0s - loss: 5.1900 - mae: 1.6951 - val_loss: 10.6559 - val_mae: 2.1617 - 72ms/epoch - 6ms/step
# Epoch 88/100
# 13/13 - 0s - loss: 5.1728 - mae: 1.6968 - val_loss: 10.5952 - val_mae: 2.1307 - 66ms/epoch - 5ms/step
# Epoch 89/100
# 13/13 - 0s - loss: 5.3196 - mae: 1.7080 - val_loss: 10.7220 - val_mae: 2.1575 - 59ms/epoch - 5ms/step
# Epoch 90/100
# 13/13 - 0s - loss: 5.2037 - mae: 1.7037 - val_loss: 10.7133 - val_mae: 2.1569 - 76ms/epoch - 6ms/step
# Epoch 91/100
# 13/13 - 0s - loss: 5.0999 - mae: 1.6712 - val_loss: 10.5274 - val_mae: 2.1150 - 81ms/epoch - 6ms/step
# Epoch 92/100
# 13/13 - 0s - loss: 5.1336 - mae: 1.6733 - val_loss: 10.4385 - val_mae: 2.1097 - 61ms/epoch - 5ms/step
# Epoch 93/100
# 13/13 - 0s - loss: 5.1272 - mae: 1.6840 - val_loss: 10.5047 - val_mae: 2.1339 - 78ms/epoch - 6ms/step
# Epoch 94/100
# 13/13 - 0s - loss: 5.1446 - mae: 1.6857 - val_loss: 10.7404 - val_mae: 2.1870 - 71ms/epoch - 5ms/step
# Epoch 95/100
# 13/13 - 0s - loss: 5.0130 - mae: 1.6726 - val_loss: 10.4397 - val_mae: 2.1087 - 77ms/epoch - 6ms/step
# Epoch 96/100
# 13/13 - 0s - loss: 5.0096 - mae: 1.6556 - val_loss: 10.5108 - val_mae: 2.1372 - 88ms/epoch - 7ms/step
# Epoch 97/100
# 13/13 - 0s - loss: 4.9347 - mae: 1.6521 - val_loss: 10.4909 - val_mae: 2.1443 - 64ms/epoch - 5ms/step
# Epoch 98/100
# 13/13 - 0s - loss: 4.9096 - mae: 1.6418 - val_loss: 10.4243 - val_mae: 2.1231 - 66ms/epoch - 5ms/step
# Epoch 99/100
# 13/13 - 0s - loss: 4.8813 - mae: 1.6338 - val_loss: 10.4950 - val_mae: 2.1464 - 75ms/epoch - 6ms/step
# Epoch 100/100
# 13/13 - 0s - loss: 4.9045 - mae: 1.6545 - val_loss: 10.4320 - val_mae: 2.1340 - 61ms/epoch - 5ms/step

# %%
### Evaluating the model
y_pred = model.predict(x_test)

rmse_test = (np.sqrt(mean_squared_error(y_test, y_pred)))
print(f'Root Mean Squared Error on Test Set: {rmse_test}')
# Out:
# 4/4 [==============================] - 0s 4ms/step
# Root Mean Squared Error on Test Set: 3.2298580007425444

# %%
r2_test = r2_score(y_test, y_pred)
print("R2 Score", r2_test)
# Out:
# R2 Score 0.8577465629701098
